# %%
import JoPy as jp

# %%
dir(jp)
# Out:
# ['Image',
#  'Nominatim',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'api',
#  'colorsys',
#  'g_to_plot',
#  'geodesic',
#  'gmap_info',
#  'gmap_png',
#  'gmap_url',
#  'math',
#  'pd',
#  'plt',
#  'urlopen']

# %%
help(jp)
# Out:
# Help on module JoPy:
#
# NAME
#     JoPy
#
# FUNCTIONS
#     api(google_api)
#
#     g_to_plot(google_api, map_center, zoom_level, map_type, grid=False)
#
#     gmap_info(google_api, map_center='California', zoom_level=6)
#
#     gmap_png(google_api, map_center, zoom_level, map_type)
#
#     gmap_url(google_api, map_center, zoom_level, map_type)
#
# FILE
#     /home/rick1270/repos/rclayton/JoPy/JoPy.py

# %%
# Redact api before deploying
goggle_api = ('AIzaSyDmUSfVjJKp8-mDbvmDE-Pmq51Jh-mRfE4')
map_center = 'dallas, texas'
zoom_level = 15
map_type = 'satellite'

# %%
jp.api(goggle_api)
# Out:
# AIzaSyDmUSfVjJKp8-mDbvmDE-Pmq51Jh-mRfE4

# %%
jp.gmap_url(goggle_api, map_center, zoom_level, map_type)
# Out:
# 'https://maps.googleapis.com/maps/api/staticmap?center=32.7762719,-96.7968559&zoom=15&size=600x600&maptype=satellite&key=AIzaSyDmUSfVjJKp8-mDbvmDE-Pmq51Jh-mRfE4'

# %%
jp.gmap_png(goggle_api, map_center, zoom_level , map_type)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=600x600 at 0x7FB4E91F5A20>

# %%
jp.gmap_info(goggle_api, map_center=map_center, zoom_level=zoom_level)
# Out:
# The coordinates at the center of the map are: latitude = 32.7762719 and longitude = -96.7968559 in Dallas, Dallas County, Texas, USA
# The map represents an area 2.410033334185586 km high and 2.410033334185586 km wide
# The borders of the map are: North = 32.78713677462479 latitude  South = 32.765407025375204 latitude  West = -96.8097179154009 longitude  East = -96.7839938845991 longitude
# The map image is 600 pixels high by 600 pixels wide with a zoom level of 15 and may be called using "map_img"
# The map url is: https://maps.googleapis.com/maps/api/staticmap?center=32.7762719,-96.7968559&zoom=15&size=600x600&key=AIzaSyDmUSfVjJKp8-mDbvmDE-Pmq51Jh-mRfE4

# %%
jp.g_to_plot(goggle_api, map_center, zoom_level, map_type='satellite', grid=False)
