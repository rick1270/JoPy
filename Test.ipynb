# %%
import JoPy as jp

# %%
dir(jp)
# Out:
# ['Image',
#  'Nominatim',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'api',
#  'colorsys',
#  'g_to_plot',
#  'geodesic',
#  'gmap_info',
#  'gmap_png',
#  'gmap_url',
#  'math',
#  'pd',
#  'plt',
#  'urlopen']

# %%
help(jp)
# Out:
# Help on module JoPy:
#
# NAME
#     JoPy
#
# FUNCTIONS
#     api(google_api)
#
#     g_to_plot(google_api, map_center, zoom_level, map_type, grid=False)
#
#     gmap_info(google_api, map_center='California', zoom_level=6)
#
#     gmap_png(google_api, map_center, zoom_level, map_type)
#
#     gmap_url(google_api, map_center, zoom_level, map_type)
#
# FILE
#     /home/rick1270/repos/rclayton/JoPy/JoPy.py

# %%
# Redact api before deploying
goggle_api = ('AIzaSyDmUSfVjJKp8-mDbvmDE-Pmq51Jh-mRfE4')
map_center = 'California'
zoom_level = 6
map_type = 'hybrid'

# %%
jp.api(goggle_api)
# Out:
# AIzaSyDmUSfVjJKp8-mDbvmDE-Pmq51Jh-mRfE4

# %%
jp.gmap_url(goggle_api, map_center, zoom_level, map_type)
# Out:
# 'https://maps.googleapis.com/maps/api/staticmap?center=36.7014631,-118.7559974&zoom=6&size=600x600&maptype=hybrid&key=AIzaSyDmUSfVjJKp8-mDbvmDE-Pmq51Jh-mRfE4'

# %%
jp.gmap_png(goggle_api, map_center, zoom_level , map_type)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=600x600 at 0x7F06B2C3B780>

# %%
jp.gmap_info(goggle_api, map_center='California', zoom_level=6)
# Out:
# The coordinates at the center of the map are: latitude = 36.7014631 and longitude = -118.7559974 in California, USA
# The map represents an area 1176.6562766629663 km high and 1176.6562766629663 km wide
# The borders of the map are: North = 42.00260347761903 latitude  South = 31.40032272238096 latitude  West = -125.33993858207745 longitude  East = -112.17205621792255 longitude
# The map image is 600 pixels high by 600 pixels wide with a zoom level of 6 and may be called using "map_img"
# The map url is: https://maps.googleapis.com/maps/api/staticmap?center=36.7014631,-118.7559974&zoom=6&size=600x600&key=AIzaSyDmUSfVjJKp8-mDbvmDE-Pmq51Jh-mRfE4

# %%
jp.g_to_plot(goggle_api, map_center, zoom_level, map_type='satellite', grid=False)
